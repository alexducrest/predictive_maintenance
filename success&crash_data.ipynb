# %%
# %cd ./drive/MyDrive/London\ EDTH\ Hackathon\ 2025
# Out:
# /content/drive/MyDrive/London EDTH Hackathon 2025

# %%
# %ls
# Out:
# crashes_successful_data/  test_data/

# %%
# %cd ./test_data/
# Out:
# /content/drive/MyDrive/London EDTH Hackathon 2025/test_data

# %%
# %ls
# Out:
# TestCheck_1/  TestCheck_2/

# %%
import os
import pandas as pd
import re

# Path to the folder containing the CSV files
folder_path = r"./TestCheck_1"

# List to hold all DataFrames
all_dfs = []

# Regex to extract sensor type and drone ID from filename
pattern = re.compile(r"(.+)_([0-9]+)\.csv")

for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        match = pattern.match(filename)
        if match:
            sensor_type = match.group(1)
            drone_id = match.group(2)
            file_path = os.path.join(folder_path, filename)
            df = pd.read_csv(file_path)
            df['sensor_type'] = sensor_type
            df['drone_id'] = drone_id
            all_dfs.append(df)

# Combine all DataFrames
if all_dfs:
    combined_df = pd.concat(all_dfs, ignore_index=True)
    # Save to a new CSV file
    combined_df.to_csv(os.path.join(folder_path, 'combined_dataset.csv'), index=False)
    print('Combined dataset saved as combined_dataset.csv')
else:
    print('No CSV files found or no data to combine.')
# Out:
# Combined dataset saved as combined_dataset.csv

# %%
# %ls
# Out:
# TestCheck_1/  TestCheck_2/

# %%
df.head()
# Out:
#        t__s     imu.p     imu.q     imu.r  imu.phi__deg  imu.theta__deg  \
# 0  0.000000 -0.002601 -0.000128 -0.001987      2.272874        4.426570
# 1  0.040000 -0.002382 -0.000128  0.001201      2.263596        4.426984
# 2  0.080001  0.000587  0.002003 -0.002207      2.259471        4.429845
# 3  0.120028  0.001577  0.003068 -0.003344      2.262854        4.432232
# 4  0.160000  0.000661 -0.000128 -0.001147      2.267947        4.433229
#
#    imu.psi__deg  imu.ax_filt  imu.ay_filt  imu.az_filt    imu.VX    imu.VY  \
# 0    -63.695394     0.664446    -0.444310    -9.727731  0.001227 -0.003885
# 1    -63.693447     0.673112    -0.421013    -9.745648  0.001638 -0.003102
# 2    -63.694519     0.697481    -0.393797    -9.772407  0.002815 -0.003293
# 3    -63.698344     0.730224    -0.382149    -9.793557 -0.000405 -0.001293
# 4    -63.702968     0.759453    -0.377445    -9.810194 -0.000404 -0.001400
#
#      imu.VZ sensor_type drone_id
# 0 -0.023496         imu     1396
# ...

# %%
df
# Out:
#                t__s     imu.p     imu.q     imu.r  imu.phi__deg  \
# 0          0.000000 -0.002601 -0.000128 -0.001987      2.272874
# 1          0.040000 -0.002382 -0.000128  0.001201      2.263596
# 2          0.080001  0.000587  0.002003 -0.002207      2.259471
# 3          0.120028  0.001577  0.003068 -0.003344      2.262854
# 4          0.160000  0.000661 -0.000128 -0.001147      2.267947
# ...             ...       ...       ...       ...           ...
# 104109  4164.368029  0.013114 -0.010984 -0.000705   -166.359065
# 104110  4164.408011  0.015166 -0.007833 -0.001909   -166.315707
# 104111  4164.448033  0.009923 -0.012140 -0.000475   -166.274713
# 104112  4164.488007  0.012189 -0.008990  0.001508   -166.242269
# 104113  4164.528022  0.013169 -0.006905  0.000377   -166.208064
#
#         imu.theta__deg  imu.psi__deg  imu.ax_filt  imu.ay_filt  imu.az_filt  \
# 0             4.426570    -63.695394     0.664446    -0.444310    -9.727731
# ...

# %%
# %cd ..
# Out:
# /

# %%
# %ls
# Out:
# bin@                        lib32@                    root/
# boot/                       lib64@                    run/
# content/                    libx32@                   sbin@
# cuda-keyring_1.1-1_all.deb  media/                    srv/
# datalab/                    mnt/                      sys/
# dev/                        NGC-DL-CONTAINER-LICENSE  tmp/
# etc/                        opt/                      tools/
# home/                       proc/                     usr/
# kaggle/                     python-apt/               var/
# lib@                        python-apt.tar.xz*

# %%
# %cd content/
# Out:
# /content

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
# %cd ./drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# %cd ./London_EDTH_Hackathon_2025/
# Out:
# /content/drive/MyDrive/London_EDTH_Hackathon_2025

# %%
# %cd ./crashes_successful_data/
# Out:
# /content/drive/MyDrive/London_EDTH_Hackathon_2025/crashes_successful_data

# %%
# %ls
# Out:
#  Crashes/  'Successful Test Flights'/

# %%
import os
import pandas as pd
import re

# Path to the folder containing the CSV files
folder_path = r"./Successful Test Flights"

# List to hold all DataFrames
all_dfs = []

# Regex to extract sensor type and drone ID from filename
pattern = re.compile(r"(.+)_([0-9]+)\.csv")

for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        match = pattern.match(filename)
        if match:
            sensor_type = match.group(1)
            drone_id = match.group(2)
            file_path = os.path.join(folder_path, filename)
            df = pd.read_csv(file_path)
            df['sensor_type'] = sensor_type
            df['drone_id'] = drone_id
            all_dfs.append(df)

# Combine all DataFrames
if all_dfs:
    combined_df = pd.concat(all_dfs, ignore_index=True)
    # Save to a new CSV file
    combined_df.to_csv(os.path.join(folder_path, 'combined_dataset_successful.csv'), index=False)
    print('Combined dataset saved as combined_dataset_successful.csv')
else:
    print('No CSV files found or no data to combine.')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3439412551.py in <cell line: 0>()
#      12 pattern = re.compile(r"(.+)_([0-9]+)\.csv")
#      13
# ---> 14 for filename in os.listdir(folder_path):
#      15     if filename.endswith('.csv'):
#      16         match = pattern.match(filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: './Successful Test Flights'

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
# %cd ./drive/
# Out:
# /content/drive

# %%
# %cd ./MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# %cd ./London_EDTH_Hackathon_2025/
# Out:
# /content/drive/MyDrive/London_EDTH_Hackathon_2025

# %%
# %cd ./crashes_successful_data/
# Out:
# /content/drive/MyDrive/London_EDTH_Hackathon_2025/crashes_successful_data

# %%
# %ls
# Out:
#  Crashes/  'Successful Test Flights'/

# %%
import os
import pandas as pd
import re

# Path to the folder containing the CSV files
folder_path = r"./Successful Test Flights"

# List to hold all DataFrames
all_dfs = []

# Regex to extract sensor type and drone ID from filename
pattern = re.compile(r"(.+)_([0-9]+)\.csv")

for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        match = pattern.match(filename)
        if match:
            sensor_type = match.group(1)
            drone_id = match.group(2)
            file_path = os.path.join(folder_path, filename)
            df = pd.read_csv(file_path)
            df['sensor_type'] = sensor_type
            df['drone_id'] = drone_id
            all_dfs.append(df)

# Combine all DataFrames
if all_dfs:
    combined_df = pd.concat(all_dfs, ignore_index=True)
    # Save to a new CSV file
    combined_df.to_csv(os.path.join(folder_path, 'combined_dataset_successful.csv'), index=False)
    print('Combined dataset saved as combined_dataset_successful.csv')
else:
    print('No CSV files found or no data to combine.')

# %%
# %cd ./drive/
# Out:
# /content/drive

# %%
# %cd ./MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# %cd ./London_EDTH_Hackathon_2025/crashes_successful_data/
# Out:
# /content/drive/MyDrive/London_EDTH_Hackathon_2025/crashes_successful_data

# %%
import os
import pandas as pd
import re

# Path to the folder containing the CSV files
folder_path = r"./Successful Test Flights"

# List to hold all DataFrames
all_dfs = []

# Regex to extract sensor type and drone ID from filename
pattern = re.compile(r"(.+)_([0-9]+)\.csv")

for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        match = pattern.match(filename)
        if match:
            sensor_type = match.group(1)
            drone_id = match.group(2)
            file_path = os.path.join(folder_path, filename)
            df = pd.read_csv(file_path)
            df['sensor_type'] = sensor_type
            df['drone_id'] = drone_id
            all_dfs.append(df)

# Combine all DataFrames
if all_dfs:
    combined_df = pd.concat(all_dfs, ignore_index=True)
    # Save to a new CSV file
    combined_df.to_csv(os.path.join(folder_path, 'combined_dataset_successful.csv'), index=False)
    print('Combined dataset saved as combined_dataset_successful.csv')
else:
    print('No CSV files found or no data to combine.')
