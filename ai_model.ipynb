# %%
# !git clone https://github.com/swardiantara/DroLoVe.git
# Out:
# Cloning into 'DroLoVe'...
# remote: Enumerating objects: 14273, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 14273 (delta 1), reused 6 (delta 0), pack-reused 14265 (from 1)
# Receiving objects: 100% (14273/14273), 54.63 MiB | 16.85 MiB/s, done.
# Resolving deltas: 100% (8488/8488), done.
# Updating files: 100% (11179/11179), done.

# %%
# !ls
# Out:
# ablation     models	       run_baseline.sh		  utils
# baseline.py  multitask.py      run_multitask.sh		  visualization
# experiments  notebooks	       run_neurallog.sh
# figures      README.md	       run_transsentlog.sh
# LICENSE      requirements.txt  train_memory_efficient.py

# %%
# %cd ./DroLoVe
# Out:
# /content/DroLoVe

# %%
# !python ./train_memory_efficient.py
# Out:
# ...
# COMPONENT HEALTH MODEL TRAINING - MEMORY EFFICIENT VERSION
# ...
# Using device: cuda
# Loading dataset: alexducrest/successful_flight_dataset
# README.md: 5.11kB [00:00, 9.77MB/s]
# data/train-00000-of-00014.parquet: 100% 22.0M/22.0M [00:00<00:00, 33.7MB/s]
# data/train-00001-of-00014.parquet: 100% 22.2M/22.2M [00:00<00:00, 71.6MB/s]
# data/train-00002-of-00014.parquet: 100% 22.9M/22.9M [00:00<00:00, 67.2MB/s]
# data/train-00003-of-00014.parquet: 100% 20.0M/20.0M [00:00<00:00, 64.3MB/s]
# data/train-00004-of-00014.parquet: 100% 18.3M/18.3M [00:00<00:00, 67.3MB/s]
# data/train-00005-of-00014.parquet: 100% 18.6M/18.6M [00:00<00:00, 64.7MB/s]
# data/train-00006-of-00014.parquet: 100% 64.5M/64.5M [00:00<00:00, 96.3MB/s]
# data/train-00007-of-00014.parquet: 100% 89.6M/89.6M [00:00<00:00, 112MB/s]
# data/train-00008-of-00014.parquet: 100% 119M/119M [00:01<00:00, 99.7MB/s]
# data/train-00009-of-00014.parquet: 100% 132M/132M [00:02<00:00, 54.4MB/s]
# ...
